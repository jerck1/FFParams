# %% [markdown]
# # QM_PARAMETERS STX

# %% [markdown]
# ## 1. B3LYP scan (6-31+G*)

# %%
#50 conf

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib notebook
matplotlib.rcParams['figure.figsize'] = (7.0, 5.0)
import numpy as np
from scipy.optimize import curve_fit

# %%
def Dieh_1ter(x,k1):
    return k1*(1+np.cos((2*x-180)*np.pi/180))

# %% [markdown]
# # 50 Conf B3 6-31+G* || MP2 6-31G*

# %%
L0_dat_CORD1 = np.genfromtxt("51_conf_B3_6_31GP.dat")
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD1_Norm=[]
for i in L0_dat_CORD1.tolist():
    CORD1_Norm.append((i-L0_dat_CORD1[0])*627.5)
for i in range(50):
    Dieh.append(init_Dieh-(i*7.4))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CORD1_Norm,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CORD1_Norm,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.22415037]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # 26 Conf B3 6-31+G* || MP2 6-31G*

# %%
L0_dat_CORD1 = np.genfromtxt("CORD1_QM_DATA.dat")
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD1_Norm=[]
for i in L0_dat_CORD1.tolist():
    CORD1_Norm.append((i-L0_dat_CORD1[0])*627.5)
for i in range(26):
    Dieh.append(init_Dieh-(i*14.4))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CORD1_Norm,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CORD1_Norm,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.22552326]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # 26 Conf B3 6-31+G* || MP2 6-31+G*

# %%
L0_dat_CORD1 = np.genfromtxt("6_31_plusG_b3mp2STXallatoms.dat")
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD1_Norm=[]
for i in L0_dat_CORD1.tolist():
    CORD1_Norm.append((i-L0_dat_CORD1[0])*627.5)
for i in range(26):
    Dieh.append(init_Dieh-(i*14.4))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CORD1_Norm,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CORD1_Norm,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [2.66834765]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # CUTL0_2

# %% [markdown]
# # B3LYP full scan

# %%
L0_dat_CORD1 = np.genfromtxt("./b3lyp_scan_CUTL02.txt")
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD1_Norm=[]
for i in L0_dat_CORD1.tolist():
    CORD1_Norm.append((i-L0_dat_CORD1[0])*627.5)
for i in range(21):
    Dieh.append(init_Dieh-(i*18))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CORD1_Norm,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CORD1_Norm,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.15383749]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# ## data MP2 full scann

# %%
L0_dat_CORD1 = np.genfromtxt("./data_CutL02_mp2_fullScan.txt")
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD1_Norm=[]
for i in L0_dat_CORD1.tolist():
    CORD1_Norm.append((i-L0_dat_CORD1[0])*627.5)
for i in range(21):
    Dieh.append(init_Dieh-(i*18))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CORD1_Norm,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CORD1_Norm,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.10059638]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # B3LYP || MP2 6-31G*

# %%
L0_dat_CORD1 = np.genfromtxt("./CORD_6_31G_d_CUTL02.dat")
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD1_Norm=[]
for i in L0_dat_CORD1.tolist():
    CORD1_Norm.append((i-L0_dat_CORD1[0])*627.5)
for i in range(21):
    Dieh.append(init_Dieh-(i*18))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CORD1_Norm,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CORD1_Norm,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.15383749]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # B3LYP | MP2 6-31+G

# %%
L0_dat_CORD1 = np.genfromtxt("./6_31_plusG_b3mp2_dat.dat")
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD1_Norm=[]
for i in L0_dat_CORD1.tolist():
    CORD1_Norm.append((i-L0_dat_CORD1[0])*627.5)
for i in range(26):
    Dieh.append(init_Dieh-(i*14.4))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CORD1_Norm,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CORD1_Norm,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [2.66834765]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # B3L | MP2 6-311+G*

# %%
Cut_L0_2_B3Mp2 = np.genfromtxt("./CUTL0_2_6_311Gd.dat")
init_Dieh=179.8675
Dieh =[]
Cut_L0_2_B3Mp2_kcal=[]
for i in Cut_L0_2_B3Mp2.tolist():
    Cut_L0_2_B3Mp2_kcal.append(((i-Cut_L0_2_B3Mp2[0])*627.5))
for i in range(21):
    Dieh.append(init_Dieh-(i*18.0))
    
popt, pcomv = curve_fit(Dieh_1ter,Dieh,Cut_L0_2_B3Mp2_kcal,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,Cut_L0_2_B3Mp2_kcal,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#lt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [2.54585644]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # Conjugated Chain

# %% [markdown]
# # B3LYP full scan

# %%
Cut_L0_2OH_B3Mp2 = np.genfromtxt("./b3lyp_full_scan_conj_chain.txt")
init_Dieh=179.8675
Dieh =[]
Cut_L0_2OH_B3Mp2_kcal=[]
for i in Cut_L0_2OH_B3Mp2.tolist():
    Cut_L0_2OH_B3Mp2_kcal.append(((i-Cut_L0_2OH_B3Mp2[0])*627.5))
for i in range(21):
    Dieh.append(init_Dieh-(i*18.0))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,Cut_L0_2OH_B3Mp2_kcal,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,Cut_L0_2OH_B3Mp2_kcal,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.76934443]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # MP2 full scan

# %%
CJ_CH_B3Mp2 = np.genfromtxt("./Mp2_Conj_Chain_all.dat")
init_Dieh=179.8675
Dieh =[]
CJ_CH_B3Mp2_kcal=[]
for i in CJ_CH_B3Mp2.tolist():
    CJ_CH_B3Mp2_kcal.append(((i-CJ_CH_B3Mp2[0])*627.5))
for i in range(31):
    Dieh.append(init_Dieh-(i*12.0))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CJ_CH_B3Mp2_kcal,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CJ_CH_B3Mp2_kcal,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.07459662]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # B3LYP || MP2 6-31G*

# %%
CJ_CH_B3Mp2 = np.genfromtxt("./COnJCha_6_31Gd.dat")
init_Dieh=179.8675
Dieh =[]
CJ_CH_B3Mp2_kcal=[]
for i in CJ_CH_B3Mp2.tolist():
    CJ_CH_B3Mp2_kcal.append(((i-CJ_CH_B3Mp2[0])*627.5))
for i in range(21):
    Dieh.append(init_Dieh-(i*18.0))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CJ_CH_B3Mp2_kcal,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CJ_CH_B3Mp2_kcal,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [3.12799225]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # B3LYP || MP2 6-31+G

# %%
CJ_CH_B3Mp2 = np.genfromtxt("./B3Mp2_6_31+_PARM_conj.dat")
init_Dieh=179.8675
Dieh =[]
CJ_CH_B3Mp2_kcal=[]
for i in CJ_CH_B3Mp2.tolist():
    CJ_CH_B3Mp2_kcal.append(((i-CJ_CH_B3Mp2[0])*627.5))
for i in range(21):
    Dieh.append(init_Dieh-(i*18.0))
popt, pcomv = curve_fit(Dieh_1ter,Dieh,CJ_CH_B3Mp2_kcal,p0=[1],bounds=((0),(100)),maxfev=10000)
Dieh=np.asarray(Dieh)
print(popt)
plt.figure()
plt.plot(Dieh,Dieh_1ter(Dieh,*popt),c='r',label=('Fit: $K $=%5.3f' % tuple(popt)))
plt.plot(Dieh,CJ_CH_B3Mp2_kcal,label='QM Data',marker="X")
plt.plot(Dieh,Dieh_1ter(Dieh,(5.875/4.186)),label="CHARMM")
plt.plot(Dieh,Dieh_1ter(Dieh,(2.175)),label="AMBER")
#plt.plot(Dieh,Dieh_1ter(Dieh,(1.03)),c='y',label="AMBER-paramfit")
plt.legend(loc=(0))
plt.ylabel("Relative Energy (kcal/mol)")
plt.xlabel('$\phi$')
# Out:
# [2.47625306]
# Text(0.5, 0, '$\\phi$')

# %% [markdown]
# # CORD2

# %%
def tor_3_term_fix_n_fix_phi(x,k1,k2,k3):
    return (k1*(1+np.cos((1*x-0)*np.pi/180)) + k2*(1+np.cos((2*x-180)*np.pi/180))+k3*(1+np.cos((3*x-0)*np.pi/180)))

# %%
CORD2_data = np.genfromtxt("./CORD2_QM_DATA.dat")
plt.figure(figsize=(8,5))
#Data extraction and preparation
init_Dieh=179.8675
Dieh =[]
CORD2_Norm=[]
for i in CORD2_data.tolist():
    CORD2_Norm.append((i-CORD2_data[0])*627.5)
for i in range(26):
    Dieh.append(init_Dieh-(i*14.4))
#fit
popt, pcomv = curve_fit(tor_3_term_fix_n_fix_phi,Dieh,CORD2_Norm,p0=[10,10,10],bounds=((0,0,0),(50,50,50)),maxfev=10000)
Dieh=np.asarray(Dieh)
print("[k1  , k2  , k3 ]")
print(popt)
p1, = plt.plot(Dieh,tor_3_term_fix_n_fix_phi(Dieh,*popt),c='r', label='Fit')
#plt.plot(Dieh,tor_3_term_fix_n_fix_phi(Dieh,1.1873,2.3955,0.3332),c='r', label='Fit_paramfit')
p2, =plt.plot(Dieh,CORD2_Norm,marker="X",label='QM Data')
p3, =plt.plot(Dieh,tor_3_term_fix_n_fix_phi(Dieh,1,(8.368/4.186),(2.092/4.186)),label="CHARMM")
p4, =plt.plot(Dieh,Dieh_1ter(Dieh,(1)),label="AMBER")
plt.legend((p2,p1,p3,p4),("QM","Fit","CHARMM","AMBER"),loc=(1.05,0.3),fontsize=14)
plt.xticks(np.arange(-180, 181, 30.0),rotation=30)
plt.yticks(fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel(" Energy (kcal/mol)",fontsize=18)
plt.xlabel(' Dihedral  ($C_{23} - C_{24} - C_{25} - C_{26}$)',fontsize=18)
plt.tight_layout()
plt.savefig("CORD2_QM_data.jpg")
# Out:
# [k1  , k2  , k3 ]
# [1.13617548 2.31581858 1.00188739]
